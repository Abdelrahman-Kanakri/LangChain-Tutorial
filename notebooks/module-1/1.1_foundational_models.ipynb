# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain_mistralai import ChatMistralAI

model = ChatMistralAI(model="mistral-small-latest")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon doesn’t have a capital—or any cities, countries, or governments—because it’s an uninhabited celestial body. However, if you\'re asking in a playful or speculative sense, here are a few fun answers:\n\n1. **Tranquility Base** – The site of the first human Moon landing (Apollo 11 in 1969), humorously dubbed the "first lunar capital" by some space enthusiasts.\n2. **Lunar Gateway** – A future NASA-led space station orbiting the Moon, which could serve as a symbolic "hub" for lunar activities.\n3. **New Armstrong City** – A fictional name sometimes used in sci-fi for a hypothetical first Moon settlement.\n4. **Mare Serenitatis** – A large lunar plain (or "sea") that’s been proposed as a potential site for future bases.\n\nIf humans ever establish permanent colonies, the first major settlement might unofficially become the "capital." For now, though, the Moon is ruled by **no one**—except maybe the **Man in the Moon** (if you believe in folklore!).\n\nWould you like ideas for a *future* lunar capital? 🚀🌕', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 11, 'total_tokens': 264, 'completion_tokens': 253}, 'model_name': 'mistral-medium-latest', 'model': 'mistral-medium-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019b8492-62de-7d40-9659-d86a70411075-0', usage_metadata={'input_tokens': 11, 'output_tokens': 253, 'total_tokens': 264})

# %%
print(response.content)
# Out:
# The Moon doesn’t have a capital—or any cities, countries, or governments—because it’s an uninhabited celestial body. However, if you're asking in a playful or speculative sense, here are a few fun answers:
#
# 1. **Tranquility Base** – The site of the first human Moon landing (Apollo 11 in 1969), humorously dubbed the "first lunar capital" by some space enthusiasts.
# 2. **Lunar Gateway** – A future NASA-led space station orbiting the Moon, which could serve as a symbolic "hub" for lunar activities.
# 3. **New Armstrong City** – A fictional name sometimes used in sci-fi for a hypothetical first Moon settlement.
# 4. **Mare Serenitatis** – A large lunar plain (or "sea") that’s been proposed as a potential site for future bases.
#
# If humans ever establish permanent colonies, the first major settlement might unofficially become the "capital." For now, though, the Moon is ruled by **no one**—except maybe the **Man in the Moon** (if you believe in folklore!).
#
# Would you like ideas for a *future* lunar capital? 🚀🌕

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'model': 'mistral-medium-latest',
#  'model_name': 'mistral-medium-latest',
#  'model_provider': 'mistralai',
#  'token_usage': {'completion_tokens': 253,
#                  'prompt_tokens': 11,
#                  'total_tokens': 264}}

# %% [markdown]
# ## Customising your Model

# %%
model = ChatMistralAI(
    model="mistral-small-latest", 
    # Kwargs passed to the model:
    temperature=1.0)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital—or any cities, countries, or governments—because it's not inhabited by humans (yet!). However, there are a few fun and speculative answers to your question:
#
# 1. **Lunar Base Alpha** – A fictional name often used in sci-fi (like *Space: 1999*) for a hypothetical human settlement.
# 2. **Tranquility Base** – The site of the first Moon landing (Apollo 11, 1969), sometimes jokingly called the "first lunar capital."
# 3. **Artemis Base Camp** – NASA's planned lunar outpost (part of the *Artemis program*), which could one day be the closest thing to a "capital" if humans establish a permanent presence.
#
# For now, though, the Moon is just a big, beautiful rock with no political divisions—just craters, dust, and the occasional rover or lander! 🌕🚀
#
# Would you like details on future lunar settlements?

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it isn't a country or a sovereign state—it's a natural satellite of Earth. However, in science fiction or fictional contexts, the Moon might have a "capital" depending on the story. For example:
#
# - In *The Moon Is a Harsh Mistress* by Robert A. Heinlein, the lunar colony's main settlement is **Luna City**.
# - In *The Expanse* series, the Moon has a major city called **Luna Base**.
# - In *Space: 1999*, the Moonbase Alpha serves as a central hub.
#
# But in reality, the Moon has no official capital or government. If you're asking about real-world lunar bases, NASA and other space agencies have plans for future habitats (like the **Artemis Program**), but no permanent settlements exist yet.
#
# Would you like details on any fictional or planned lunar cities?

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or a sovereign entity—it's a natural satellite of Earth. However, in science fiction and pop culture, there are fictional "capitals" or major lunar cities, such as:
#
# 1. **Clavius Base** – A fictional NASA base in *2001: A Space Odyssey* and *The Expanse*.
# 2. **Luna City** – A common name for lunar settlements in various sci-fi works.
# 3. **Tycho City** – Featured in *The Moon Is a Harsh Mistress* by Robert A. Heinlein.
#
# If you're asking about real-world plans, NASA's **Artemis program** aims to establish a sustainable human presence on the Moon, possibly near the **South Pole** (where water ice exists). But no official "capital" has been designated yet!
#
# Would you like details on real or fictional lunar cities? 🚀🌕

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model) # we can use the model we have already assign it into a variable or explicitly define the name directly...

# %%
agent = create_agent(model="claude-sonnet-4-5") # Note: you need to change this to your model.

# %%
agent = create_agent("gpt-5-nano") # Note: you need to change this to your model.

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='c1e6242f-9329-4316-92c6-57e09c4543d2'),
#               AIMessage(content='The Moon doesn\'t have a capital because it\'s not a country or a sovereign state—it\'s Earth\'s natural satellite. However, in science fiction and popular culture, some imaginary or fictional capitals of the Moon have been proposed. For example:\n\n1. **Luna City** – A fictional lunar city often referenced in sci-fi works.\n2. **Clavius Base** – Named after the lunar crater, it appears in *2001: A Space Odyssey* and other stories.\n3. **Tycho City** – Another fictional lunar settlement, named after the Tycho crater.\n\nIn reality, no permanent human settlements exist on the Moon, though NASA\'s Artemis program and other space agencies plan to establish bases there in the future. If a lunar colony were to develop, it might eventually have a "capital" or central hub, but that hasn\'t happened yet.\n\nWould you like to explore fictional lunar cities in more detail? 🚀🌕', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 11, 'total_tokens': 209, 'completion_tokens': 198}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019b84a6-39b1-7e82-99e9-2303b729df2a-0', usage_metadata={'input_tokens': 11, 'output_tokens': 198, 'total_tokens': 209})]}

# %%
print(response["messages"][-1].content) # by using the index we can access the last message such [-1]
# Out:
# The Moon doesn't have a capital because it's not a country or a sovereign state—it's Earth's natural satellite. However, in science fiction and popular culture, some imaginary or fictional capitals of the Moon have been proposed. For example:
#
# 1. **Luna City** – A fictional lunar city often referenced in sci-fi works.
# 2. **Clavius Base** – Named after the lunar crater, it appears in *2001: A Space Odyssey* and other stories.
# 3. **Tycho City** – Another fictional lunar settlement, named after the Tycho crater.
#
# In reality, no permanent human settlements exist on the Moon, though NASA's Artemis program and other space agencies plan to establish bases there in the future. If a lunar colony were to develop, it might eventually have a "capital" or central hub, but that hasn't happened yet.
#
# Would you like to explore fictional lunar cities in more detail? 🚀🌕

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='84645f7a-40e9-4536-8ff6-13ba5a026f26'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='4120669a-1740-4c76-a32b-e54a65223e5b'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='925e82b6-0aa8-4387-ae30-e7bd76c8d0c8'),
#               AIMessage(content='Ah, *Luna City*—the bustling metropolis of the Moon! While it doesn’t exist in reality (yet), science fiction and futurist visions have long imagined what a lunar capital might look like. Here’s a fun breakdown of what *Luna City* could be:\n\n### **Location & Infrastructure**\n- **Lunar Surface or Underground?**\n  - Some concepts place Luna City on the surface, protected by domes or radiation shields.\n  - Others envision it buried beneath the Moon’s regolith (soil) to shield inhabitants from cosmic rays and extreme temperatures.\n- **Key Sites:**\n  - *Luna Port* – A major spaceport for Earth-Moon shuttles.\n  - *The Grand Dome* – A massive transparent habitat where lunar settlers live and work.\n  - *The Lunar Mining District* – Extracting helium-3 for fusion energy and water ice for life support.\n\n### **Government & Culture**\n- **Moon Colonies as Independent or Earth-Aligned?**\n  - Some stories depict Luna City as a self-governing lunar republic.\n  - Others imagine it as a joint Earth-Moon administration (maybe even a "Lunar League" with other space colonies).\n- **Culture:**\n  - A mix of Earth expats, scientists, and lunar-born citizens ("Lunarians").\n  - Low-gravity sports, zero-gravity art, and Moon-specific cuisine (like freeze-dried "Moon coffee").\n\n### **Challenges**\n- **Survival:** Limited resources, extreme cold, and radiation.\n- **Politics:** Tensions between Earth governments and lunar independence movements.\n- **Economy:** Mining, tourism, and research drive the lunar economy.\n\n### **Real-World Inspirations**\n- **NASA’s Artemis Program** aims to establish a sustainable lunar base by the 2030s.\n- **Private Companies** like SpaceX and Blue Origin are designing lunar landers.\n- **Science Fiction:** *The Moon Is a Harsh Mistress* (Heinlein), *Artemis* (Stephenson), and *Luna* (Wagner) all explore lunar societies.\n\nSo while *Luna City* isn’t real yet, it’s a fascinating thought experiment—and maybe one day, it will be! Would you want to live there? 🌕🚀', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 32, 'total_tokens': 515, 'completion_tokens': 483}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019b84a4-bde7-76f2-8be5-cf5824af08b0-0', usage_metadata={'input_tokens': 32, 'output_tokens': 483, 'total_tokens': 515})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content: # Check if there's actual content
        print(token.content, end="", flush=True) # Print token
# Out:
# Luna City, the capital of the Moon, is a fascinating concept that blends science fiction, futurism, and real-world space exploration aspirations. While no such city currently exists, the idea of a lunar metropolis has been explored in literature, film, and by space agencies like NASA and private companies like SpaceX. Here’s a detailed look at what Luna City might entail:
#
# ### **1. Location & Infrastructure**
# - **Site Selection**: Luna City would likely be built in a location with easy access to resources and favorable environmental conditions. Potential sites include:
#   - **Polar Regions**: Near the Moon’s poles, where water ice is abundant in permanently shadowed craters (e.g., Shackleton Crater).
#   - **Lunar Maria (Seas)**: Flat, volcanic plains like Mare Tranquillitatis (where Apollo 11 landed) offer stable terrain for construction.
#   - **Peaks of Eternal Light**: Areas near the poles that receive near-constant sunlight, ideal for solar power.
#
# - **Habitat Design**:
#   - **Underground or Pressurized Domes**: To protect from radiation, micrometeorites, and extreme temperature swings.
#   - **3D-Printed Structures**: Using lunar regolith (Moon soil) to build radiation-shielded habitats.
#   - **Modular Expandable Habitats**: Like NASA’s Lunar Gateway or SpaceX’s Starship-derived habitats.
#
# ### **2. Population & Governance**
# - **Residents**: A mix of scientists, engineers, miners, entrepreneurs, and possibly tourists.
# - **Governance**: Likely a joint effort between international space agencies (NASA, ESA, CNSA, etc.) and private companies, with a governance model similar to the International Space Station (ISS) or a lunar treaty.
#
# ### **3. Economy & Industry**
# - **Resource Extraction**:
#   - **Helium-3**: A potential fusion fuel mined from the lunar surface.
#   - **Water Ice**: Converted into drinking water, oxygen, and rocket fuel (via electrolysis).
#   - **Regolith Mining**: For construction materials and metals.
# - **Tourism & Research**: Lunar hotels, observatories, and scientific labs.
# - **Manufacturing**: Low-gravity production of advanced materials and pharmaceuticals.
#
# ### **4. Transportation & Logistics**
# - **Lunar Landers**: Regular flights from Earth (e.g., SpaceX Starship, NASA’s Artemis program).
# - **Surface Transport**: Pressurized rovers, magnetic levitation (maglev) trains, or even lunar elevators.
# - **Spaceports**: Launch pads for missions to Earth, Mars, or asteroid mining.
#
# ### **5. Challenges & Solutions**
# - **Radiation**: Thick regolith shielding or underground habitats.
# - **Low Gravity (1/6th of Earth’s)**: Health risks like muscle/bone loss; artificial gravity solutions may be needed.
# - **Extreme Temperatures**: Ranging from -173°C (-280°F) to 127°C (260°F); thermal regulation systems required.
# - **Supply Dependence**: Initial reliance on Earth for food and equipment, but eventually, closed-loop life support systems.
#
# ### **6. Cultural & Scientific Impact**
# - **First Off-World City**: A symbol of human expansion beyond Earth.
# - **Research Hub**: Astronomy, geology, and deep-space mission planning.
# - **Art & Culture**: Lunar museums, theaters, and even sports (low-gravity sports like "lunar basketball").
#
# ### **7. Real-World Plans**
# - **NASA’s Artemis Program**: Aims to establish a sustainable lunar presence by the 2030s.
# - **SpaceX’s Starship**: Designed for lunar and Martian colonization.
# - **Private Companies**: Blue Origin, ESA, and others are developing lunar landers and habitats.
#
# ### **8. Science Fiction Depictions**
# - **The Moon Is a Harsh Mistress** (Heinlein) – A lunar colony rebels against Earth.
# - **Artemis** (Andy Weir) – A near-future lunar city with a thriving economy.
# - **Moonbase Alpha** (TV series) – A fictional lunar colony.
#
# ### **Conclusion**
# Luna City represents humanity’s next giant leap—from a temporary outpost to a thriving lunar metropolis. While still in the planning stages, advancements in technology and international cooperation could make this vision a reality within the next few decades.
#
# Would you like details on specific aspects, like architecture, energy sources, or governance models?
