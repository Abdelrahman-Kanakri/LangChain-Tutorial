# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# from langchain_mistralai import ChatMistralAI
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
#model = ChatMistralAI(model_name="pixtral-large-latest")

# %%
from langchain.agents import create_agent

agent = create_agent(
    #model='gpt-5-nano',
    model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text",
     "text": "What is the capital of The Moon?"},
    {"type": "text",
     "text": "What is the capital of The France?"} # here how you can embed a two messages in one content block
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Okay, let's establish some facts within the realm of speculative fiction!
#
# ---
#
# **The Capital of The Moon:**
#
# The capital of The Moon is **Selenius Prime**.
#
# Nestled within the vast, ancient Mare Imbrium, Selenius Prime is not a city built on the surface, but rather an intricate, multi-layered complex carved deep into the lunar regolith and bedrock. Its heart lies beneath a colossal, translucent aerogel dome that filters harsh solar radiation while allowing a breathtaking view of the Earth-rise.
#
# **Selenius Prime** is a marvel of zero-gravity architecture and geothermal engineering. It's a bustling hub of scientific research, astromining operations, and interplanetary diplomacy. Its districts are connected by magnetic levitation tunnels and zero-G transit tubes, leading to hydroponic farms that glow with artificial sunlight, advanced laboratories humming with cutting-edge AI, and vibrant biodomes where modified Earth flora thrives. The uppermost levels, just beneath the dome, house governmental facilities for the Lunar Commonwealth, luxurious residential zones, and observation platforms offering unparalleled vistas of the lunar landscape and the distant, sapphire Earth. Its deepest sectors house critical life support, fusion reactors, and cryo-vaults of vital Earth biodiversity.
#
# ---
#
# **The Capital of The France:**
#
# Assuming you mean **France**, the capital city is **Paris**.
#
# Even in a future with lunar colonies and interstellar travel, Paris would likely remain a cherished historical and cultural nexus on Earth, perhaps enhanced with anti-gravity transit, vertical gardens, and clean energy infrastructure, but still retaining its iconic landmarks and unique charm.

# %%
for token, metadata in agent.stream(
    {"messages": [question]}, 
    stream_mode = "messages"
):
    if token.content:
        print(token.content, end="", flush=True)
# Out:
# Okay, let's establish these capitals in the grand tapestry of the future!
#
# For **The Moon**:
#
# The capital of The Moon is **Selenia Prime**.
#
# Built into the colossal, perpetually shadowed caldera of Malapert Mountain near the lunar south pole, Selenia Prime is a marvel of geomodified architecture and advanced life support. Its multi-tiered domes, interconnected by high-speed maglev tunnels, house the Lunar Governance Council, the primary scientific research facilities, and the central command for orbital traffic and resource extraction operations across the entire lunar surface. Powered by a fusion reactor deep within the lunar crust and sustained by vast reserves of polar ice, Selenia Prime is a glittering testament to humanity's enduring presence beyond Earth, a beacon of progress in the vacuum.
#
# ---
#
# For **The France**:
#
# The capital of The France (assuming you mean the nation of France on Earth) is **Paris**.
#
# Even in a future often marked by grand space-faring empires and sprawling arcologies, the ancient city of Paris endures. While its historic core remains largely preserved as a cultural heritage site, vibrant new districts of vertical farms and smart infrastructure have woven themselves into its fabric. Paris remains a global nexus of art, fashion, gastronomy, and diplomacy, serving as the administrative and cultural heart of the French Republic and a key player in Earth's political landscape.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'Roman-theatre-ruins-city-Jordan-Amman.png', 'type': 'image/png', 'size': 571982, 'content': <memory at 0x0000020510650F40>, 'last_modified': datetime.datetime(2026, 1, 4, 11, 1, 31, 826000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]},
    #model="pixtral-large-latest", 
    #stream_mode="stream"
)   

print(response['messages'][-1].content)
# Out:
# Welcome to **Aethelgard**, the capital of the Aridian Hegemony, nestled within the colossal Xylos Canyon on the planet Xylos-7.
#
# Aethelgard is a city of layers, a testament to centuries of relentless expansion and profound mystery. Its origins trace back to the first human settlers, who discovered the massive natural amphitheater, not quite natural, but a perfectly preserved relic of a pre-human, unknown civilization. This colossal stone structure, known now as the **Grand Echo Amphitheater**, became the gravitational center around which the city slowly spiraled upwards, clinging to the canyon walls like petrified vines.
#
# **The Grand Echo Amphitheater:** This isn't merely an ancient monument; it's the beating heart of the Hegemony. Its original purpose is still debated by xenolinguists and archaeo-historians, but its immense size and uncanny acoustic properties suggested it was a place of assembly or perhaps even resonant energy manipulation. Today, its ancient tiers are equipped with neural-interface seating and holographic projectors, making it the primary forum for the Aridian Hegemony's planetary council, inter-system trade negotiations, and grand cultural festivals. During crucial votes or historical commemorations, its ancient stones still hum with a faint, resonant energy, a phenomenon that gave the structure its name – the "Echoes" of a lost world.
#
# **The Terraced City:** Above and around the amphitheater, Aethelgard climbs the steep canyon sides.
#
# *   **The Lower Basin:** Immediately surrounding the Grand Echo, this is the oldest part of Aethelgard. Built from locally quarried synth-stone that mimics the amphitheater's original material, it's a dense maze of artisan workshops, data-archive libraries, and traditional food vendors. The "Street of Whispers," a winding thoroughfare, is where older generations reside, preserving the customs and data-reels from the initial colonization. The public plaza in front of the amphitheater, with its genetically engineered xeno-flora and flags of allied star systems, serves as a popular gathering point.
#
# *   **The Mid-Levels:** As the city ascends, the architecture transitions. These levels are characterized by multi-story habitat modules, interconnected by sky-bridges and dedicated grav-lift shafts. Automated transport caravans (like those seen on the roads) navigate meticulously maintained auto-lanes that spiral upwards, carrying citizens and goods. Public gardens with arid-adapted flora are interspersed, providing bursts of green against the predominant ochre and cream facades. These levels house most of the residential sectors, commercial hubs, and entertainment districts.
#
# *   **The Upper Terraces:** Clinging to the highest, sun-drenched peaks of the canyon, these are the domains of the Aridian Hegemony's administrative centers, high-tier research facilities, and the atmospheric moisture farms. These massive condensers draw precious water from the planet's thin upper atmosphere, providing vital resources to the city below. The buildings here are sleeker, gleaming with solar-collecting panels and panoramic views of the canyon and the distant, dusty plains of Xylos-7.
#
# Aethelgard is a city where history is not just revered but actively integrated into daily life. From the whispers of ancient technology emanating from the Grand Echo to the futuristic data streams flickering across holographic billboards on centuries-old walls, it is a living testament to humanity's ability to build a vibrant future atop the enigmatic foundations of the past.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")

print(aud_b64)
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.89it/s]
# Done.
# ...

# %%
agent = create_agent(
   # model='gpt-4o-audio-preview',
   model, 
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# The audio features a male voice, likely an adult, speaking English. He has a non-native English accent, possibly European (the specific country is difficult to pinpoint without more speech).
#
# He says: "One minute, I say, of cats, please, and their type."
#
# The recording quality is clear, with no obvious background noise. The speaker's tone is neutral and informative.
