# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="mistral-small-latest",
    tools=[tool1], # here where I can add a full tool into the agent.
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.61018278497431.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='61d02c66-2ad3-48c3-ba07-89b52953d575'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ANZ3nbpsz', 'function': {'name': 'square_root', 'arguments': '{"x": 467}'}, 'index': 0}]}, response_metadata={'token_usage': {'prompt_tokens': 96, 'total_tokens': 109, 'completion_tokens': 13}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'tool_calls', 'model_provider': 'mistralai'}, id='lc_run--019b8871-e444-7f72-9f5d-a5f687071375-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'ANZ3nbpsz', 'type': 'tool_call'}], usage_metadata={'input_tokens': 96, 'output_tokens': 13, 'total_tokens': 109}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='a13a841f-04f0-40ec-9612-1c2fb364ca48', tool_call_id='ANZ3nbpsz'),
#  AIMessage(content='The square root of 467 is approximately 21.61018278497431.', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 140, 'total_tokens': 170, 'completion_tokens': 30}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019b8871-e68e-7060-8758-24a99c0f6762-0', usage_metadata={'input_tokens': 140, 'output_tokens': 30, 'total_tokens': 170})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'ANZ3nbpsz', 'type': 'tool_call'}]
