# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
model = "mistral-small-latest"

# %%
from langchain.agents import create_agent


agent = create_agent(model)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='74d82fa2-c4aa-41a9-aa15-131d3022b8d7'),
#               AIMessage(content="Hello Seán! It's great to meet you. Green is a fantastic colour—it's the colour of nature, growth, and freshness. Do you have a favourite shade of green, like emerald, lime, or forest green? Or is there something special about green that you love? 😊", additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 15, 'total_tokens': 79, 'completion_tokens': 64}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019b888b-8234-7333-b42d-ecc3078ea500-0', usage_metadata={'input_tokens': 15, 'output_tokens': 64, 'total_tokens': 79})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='05318148-329c-4b34-8fa0-d687e410a90c'),
#               AIMessage(content='I don’t have access to personal information about you, so I can’t tell you your favorite color! If you’d like to share it, I’d be happy to chat about it. 😊 What’s a color that makes you happy or reminds you of something special?', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 9, 'total_tokens': 66, 'completion_tokens': 57}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019b888b-92ed-7d10-9f31-c866bd559455-0', usage_metadata={'input_tokens': 9, 'output_tokens': 57, 'total_tokens': 66})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  

agent = create_agent(
    model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='38827eb8-d4c7-402a-9246-fa49a878c57e'),
#               AIMessage(content='Hello Seán! 🌿 It\'s great to meet you and learn that your favorite color is green—what a vibrant and refreshing choice! 🎨\n\nIf you\'d like, I can suggest some fun green-themed things to explore, like:\n- **Nature spots** (forests, parks, or gardens)\n- **Green foods** (like avocados, kiwis, or matcha)\n- **Green fashion** (clothing, decor, or accessories)\n- **Green activities** (hiking, painting, or even "green" tech like eco-friendly gadgets)\n\nOr, if you\'re up for it, I can help with anything else—like jokes, trivia, or even a quick chat! 😊 What’s on your mind today?', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 15, 'total_tokens': 176, 'completion_tokens': 161}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019b888c-1f29-79f1-b7a9-0ff38c47a56c-0', usage_metadata={'input_tokens': 15, 'output_tokens': 161, 'total_tokens': 176})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='38827eb8-d4c7-402a-9246-fa49a878c57e'),
#               AIMessage(content='Hello Seán! 🌿 It\'s great to meet you and learn that your favorite color is green—what a vibrant and refreshing choice! 🎨\n\nIf you\'d like, I can suggest some fun green-themed things to explore, like:\n- **Nature spots** (forests, parks, or gardens)\n- **Green foods** (like avocados, kiwis, or matcha)\n- **Green fashion** (clothing, decor, or accessories)\n- **Green activities** (hiking, painting, or even "green" tech like eco-friendly gadgets)\n\nOr, if you\'re up for it, I can help with anything else—like jokes, trivia, or even a quick chat! 😊 What’s on your mind today?', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 15, 'total_tokens': 176, 'completion_tokens': 161}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019b888c-1f29-79f1-b7a9-0ff38c47a56c-0', usage_metadata={'input_tokens': 15, 'output_tokens': 161, 'total_tokens': 176}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='70e8ff5f-7039-40fb-a4e2-6d9a179b9316'),
#               AIMessage(content='You told me earlier that your favorite color is **green**! 🌿✨\n\n(Unless you’ve changed your mind since then—colors can be fickle, after all! 😄)\n\nWant to talk about why you love green, or maybe explore other colors too? Let me know! 🎨', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 184, 'total_tokens': 251, 'completion_tokens': 67}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019b888c-2f6b-7e80-923a-178483e427e3-0', usage_metadata={'input_tokens': 184, 'output_tokens': 67, 'total_tokens': 251})]}
